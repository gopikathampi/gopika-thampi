# %%
#Importing necessary Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read the Dataset to the python Environment

# %%
#Loading dataset

data=pd.read_csv('data_car.csv')
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
#This displays top 5 rows

data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
#This provides some information regarding the columns in the data

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
#Checking shape of the dataset

data.shape
# Out:
# (11914, 16)

# %%
#Checking skewness of the data

freqgraph=data.select_dtypes(include=['float'])
freqgraph.hist(figsize=(20,15))
plt.show()

# %%
#This displays the datatypes

data.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
#This describes the basic stat behind the dataset used

data.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
#Checking null values

data.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
#Checking unique values

data['MSRP'].unique()
# Out:
# array([46135, 40650, 36350, ..., 46120, 50620, 50920], dtype=int64)

# %%
#Checking how many unique values in the target column

data['MSRP'].nunique()
# Out:
# 6049

# %%
#This checks duplicates in the dataset

data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
#Checking the correlation between the independent variable and dependent variable

corrmatrix=data.corr()
plt.subplots(figsize=(10,4))
sns.heatmap(corrmatrix,annot=True,vmin=-0.5,vmax=1,linewidth=0.3,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Pre-processing

# %%
#Checking missing values

data.isna().sum()

# %% [markdown]
# Handling missing values

# %%
#Dropping the column market category as it has large number of missing values or is irrelevant to data analysis

data.drop('Market Category', axis=1, inplace=True)

# %%
#Handling Missing values for the categorical column

data['Engine Fuel Type'].fillna(data['Engine Fuel Type'].mode()[0], inplace=True)

# %%
#Handling missing values for the numerical columns

data['Engine HP'].fillna(data['Engine HP'].mean(), inplace=True)

# %%
data['Engine Cylinders'].fillna(data['Engine Cylinders'].mean(), inplace=True)

# %%
data['Number of Doors'].fillna(data['Number of Doors'].mean(), inplace=True)

# %%
#Checking whether missing values are handled or not
data.isna().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
org_data=data.copy()

# %%
#Label Encoding

from sklearn.preprocessing import LabelEncoder
#Creating Instance
le=LabelEncoder()
data['Make']=le.fit_transform(data['Make'])
data['Model']=le.fit_transform(data['Model'])
data['Engine Fuel Type']=le.fit_transform(data['Engine Fuel Type'])
data['Transmission Type']=le.fit_transform(data['Transmission Type'])
data['Driven_Wheels']=le.fit_transform(data['Driven_Wheels'])
data['Vehicle Style']=le.fit_transform(data['Vehicle Style'])
data['Vehicle Size']=le.fit_transform(data['Vehicle Size'])
data['Year']=le.fit_transform(data['Year'])
data
# Out:
#        Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0         4      1    21                 8      335.0               6.0
# 1         4      0    21                 8      300.0               6.0
# 2         4      0    21                 8      300.0               6.0
# 3         4      0    21                 8      230.0               6.0
# 4         4      0    21                 8      230.0               6.0
# ...     ...    ...   ...               ...        ...               ...
# 11909     0    901    22                 8      300.0               6.0
# 11910     0    901    22                 8      300.0               6.0
# 11911     0    901    22                 8      300.0               6.0
# 11912     0    901    23                 7      300.0               6.0
# 11913    25    902    16                 9      221.0               6.0
#
#        Transmission Type  Driven_Wheels  Number of Doors  Vehicle Size  \
# ...

# %% [markdown]
# Checking for Outliers and Plotting boxplot

# %%
for i in data:
    sns.boxplot(x=data[i])
    plt.show()

# %%
#Columns having outliers

Year,Engine Fuel Type,Engine HP,Engine Cylinders,Transmission Type,highway MPG,city mpg,Popularity,MSRP

# %%
from scipy import stats

# %% [markdown]
# Treating Outliers

# %%
columns_to_remove_outliers = ['Year','Engine Fuel Type','Engine HP','Engine Cylinders','Transmission Type','highway MPG','city mpg','Popularity','MSRP']

# %%
# Define the threshold for outliers (in terms of z-score)
threshold = 3

# Function to remove outliers using z-score method
def remove_outliers_zscore(data, column):
    z_scores = (data[column] - data[column].mean()) / data[column].std()
    outliers = np.abs(z_scores) > threshold
    data_no_outliers = data.loc[~outliers]
    return data_no_outliers

# Iterate over the selected columns and remove outliers
for column in columns_to_remove_outliers:
    data = remove_outliers_zscore(data, column)

# %%
#Plotting box plot 
for i in data:
    sns.boxplot(x=data[i])
    plt.show()

# %%
#Splitting the data into independent (predictor)and dependent column (target) and dropping the target column

y=data['MSRP']
x=data.drop(['MSRP'],axis=1)
y
# Out:
# 0        46135
# 1        40650
# 2        36350
# 3        29450
# 4        34500
#          ...
# 11909    46120
# 11910    56670
# 11911    50620
# 11912    50920
# 11913    28995
# Name: MSRP, Length: 10565, dtype: int64

# %%
x
# Out:
#        Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0         4      1    21                 8      335.0               6.0
# 1         4      0    21                 8      300.0               6.0
# 2         4      0    21                 8      300.0               6.0
# 3         4      0    21                 8      230.0               6.0
# 4         4      0    21                 8      230.0               6.0
# ...     ...    ...   ...               ...        ...               ...
# 11909     0    901    22                 8      300.0               6.0
# 11910     0    901    22                 8      300.0               6.0
# 11911     0    901    22                 8      300.0               6.0
# 11912     0    901    23                 7      300.0               6.0
# 11913    25    902    16                 9      221.0               6.0
#
#        Transmission Type  Driven_Wheels  Number of Doors  Vehicle Size  \
# ...

# %% [markdown]
# Scaling and Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.DataFrame(data)
df
# Out:
#        Make  Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0         4      1    21                 8      335.0               6.0
# 1         4      0    21                 8      300.0               6.0
# 2         4      0    21                 8      300.0               6.0
# 3         4      0    21                 8      230.0               6.0
# 4         4      0    21                 8      230.0               6.0
# ...     ...    ...   ...               ...        ...               ...
# 11909     0    901    22                 8      300.0               6.0
# 11910     0    901    22                 8      300.0               6.0
# 11911     0    901    22                 8      300.0               6.0
# 11912     0    901    23                 7      300.0               6.0
# 11913    25    902    16                 9      221.0               6.0
#
#        Transmission Type  Driven_Wheels  Number of Doors  Vehicle Size  \
# ...

# %%
#Creating instance

scaler=MinMaxScaler()
scaled_data=pd.DataFrame(scaler.fit_transform(df),columns=df.columns)
scaled_data
# Out:
#            Make     Model      Year  Engine Fuel Type  Engine HP  \
# 0      0.085106  0.001094  0.739130               0.8   0.676329
# 1      0.085106  0.000000  0.739130               0.8   0.591787
# 2      0.085106  0.000000  0.739130               0.8   0.591787
# 3      0.085106  0.000000  0.739130               0.8   0.422705
# 4      0.085106  0.000000  0.739130               0.8   0.422705
# ...         ...       ...       ...               ...        ...
# 10560  0.000000  0.985777  0.782609               0.8   0.591787
# 10561  0.000000  0.985777  0.782609               0.8   0.591787
# 10562  0.000000  0.985777  0.782609               0.8   0.591787
# 10563  0.000000  0.985777  0.826087               0.6   0.591787
# 10564  0.531915  0.986871  0.521739               1.0   0.400966
#
#        Engine Cylinders  Transmission Type  Driven_Wheels  Number of Doors  \
# 0                   0.6               0.75       1.000000              0.0
# ...

# %%
#Plot Entire DataSet

for i in df:
    fig,ax=plt.subplots(1,2)
    sns.distplot(df[i],ax=ax[0])
    ax[0].set_title("Original Data")
    sns.distplot(scaled_data[i],ax=ax[1])
    ax[1].set_title("Scaled Data")
# Out:
# C:\Users\Gopika\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Gopika\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Normalization

# %%
from sklearn import preprocessing

# %%
df = preprocessing.normalize(data)
normalized_data = pd.DataFrame(df, columns=data.columns)
normalized_data
# Out:
#            Make     Model      Year  Engine Fuel Type  Engine HP  \
# 0      0.000086  0.000022  0.000454          0.000173   0.007235
# 1      0.000098  0.000000  0.000514          0.000196   0.007346
# 2      0.000109  0.000000  0.000574          0.000219   0.008205
# 3      0.000135  0.000000  0.000707          0.000269   0.007741
# 4      0.000115  0.000000  0.000605          0.000230   0.006624
# ...         ...       ...       ...               ...        ...
# 10560  0.000000  0.019532  0.000477          0.000173   0.006503
# 10561  0.000000  0.015897  0.000388          0.000141   0.005293
# 10562  0.000000  0.017796  0.000435          0.000158   0.005925
# 10563  0.000000  0.017691  0.000452          0.000137   0.005891
# 10564  0.000862  0.031093  0.000552          0.000310   0.007618
#
#        Engine Cylinders  Transmission Type  Driven_Wheels  Number of Doors  \
# 0              0.000130           0.000065       0.000065         0.000043
# ...

# %%
#Plot entire DataSet

for i in data :
    fig,ax=plt.subplots(1,2)
    sns.distplot(data[i],ax=ax[0])
    ax[0].set_title("Original Data")
    sns.distplot(normalized_data[i],ax=ax[1])
    ax[1].set_title("Normalized Data")
# Out:
# C:\Users\Gopika\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Gopika\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# Splitting The Dataset Into The Training Set And Test Set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)

# %%
#Importing the models

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\gopika\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\gopika\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\gopika\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\gopika\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\gopika\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\gopika\anaconda3\lib\site-packages)

# %%
#Importing the models

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %% [markdown]
# # Model Training

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)

rf = RandomForestRegressor()
rf.fit(x_train,y_train)

xgb = GradientBoostingRegressor()
xgb.fit(x_train,y_train)

xg = XGBRegressor()
xg.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %% [markdown]
# Prediction On Test Data

# %%
y_pred1 = lr.predict(x_test)
y_pred2 = rf.predict(x_test)
y_pred3 = xgb.predict(x_test)
y_pred4 = xg.predict(x_test)

# %% [markdown]
# Evaluating the Algorithm

# %%
from sklearn import metrics

# %%
score1 = metrics.r2_score(y_test,y_pred1)
score2 = metrics.r2_score(y_test,y_pred2)
score3 = metrics.r2_score(y_test,y_pred3)
score4 = metrics.r2_score(y_test,y_pred4)
print(score1,score2,score3,score4)
# Out:
# 0.7208133866696057 0.9595558619216357 0.9069210764209583 0.9643621735752853

# %%
final_data = pd.DataFrame({'Models':['LR','RF','GBR','XG'],
             "R2_SCORE":[score1,score2,score3,score4]})
final_data
# Out:
#   Models  R2_SCORE
# 0     LR  0.720813
# 1     RF  0.959556
# 2    GBR  0.906921
# 3     XG  0.964362

# %%
#XGB has the highest accuracy score

# %% [markdown]
# Saving the Model

# %%
xg = XGBRegressor()
xg_final = xg.fit(x,y)

# %%
import joblib

# %%
joblib.dump(xg_final,'car_price_predictor')
# Out:
# ['car_price_predictor']

# %%
model = joblib.load('car_price_predictor')
model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
